# %% [markdown]
# <a href="https://colab.research.google.com/github/JYchoi22117/SSHS_2401/blob/main/practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 0. Google Colab 환경 세팅
#
# - 런타임 유형 변경: T4 GPU (저장)
#
# ### 1. 내 드라이브 연결 (1~2분 소요)
#
# - 내 드라이브 연결
# - 작업 Directory 이동

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# practice로 폴더 생성하지 않고 본인의 폴더명을 별도로 설정하였을 경우, 해당 폴더명을 넣어주기
# %cd ./drive/MyDrive/practice
# Out:
# /content/drive/MyDrive/practice

# %%
# 현재 directory 확인
# %pwd
# Out:
# '/content/drive/MyDrive/practice'

# %% [markdown]
# ### 2. 분석에 필요한 모듈 및 라이브러리 설치
#
# - Google colab에서 기본적으로 제공하는 모듈도 있음
# - 이 외 모듈은 pip install 명령어를 통해 설치
# - 설치에는 2~3분 소요

# %%
# pip install 설치 명령어

# 한국어 형태소 분석기
# !pip install konlpy
# !pip install kiwipiepy

# 데이터 - excel 파일 열기
# !pip install openpyxl

# 모델
# !pip install keybert
# !pip install bertopic
# !pip install sentence_transformers
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 47.6 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 48.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.2)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.3 MB/s eta 0:00:00
# Collecting kiwipiepy-model~=0.16 (from kiwipiepy)
#   Downloading kiwipiepy_model-0.16.0.tar.gz (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from kiwipiepy) (1.23.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kiwipiepy) (4.66.1)
# Building wheels for collected packages: kiwipiepy-model
#   Building wheel for kiwipiepy-model (setup.py) ... done
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0.16.0-py3-none-any.whl size=30813256 sha256=20039733968793fde597b733b2ea6affb3008d6b930b43dc52e500c11be9edc4
#   Stored in directory: /root/.cache/pip/wheels/6b/03/2b/ac2c97cc65ebd9df3516f4b900adc2f0a744df8d1375b2e2ef
# Successfully built kiwipiepy-model
# Installing collected packages: kiwipiepy-model, kiwipiepy
# Successfully installed kiwipiepy-0.16.2 kiwipiepy-model-0.16.0
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Collecting keybert
#   Downloading keybert-0.8.3.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.3.8 (from keybert)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.23.5)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.16.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.3.8->keybert)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.20.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (23.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.3-py3-none-any.whl size=39124 sha256=ce482de4ac1c5bed173eaa97474dc308c72262b2b018ec4a1a44470eee589dc3
#   Stored in directory: /root/.cache/pip/wheels/70/88/07/1a3bc11fd1dd5f89924a02dcbca89a3015e25e8faa31f904dc
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=93af30835fed1709258fbb7aff32118e8c8dec117a5cbc804c34bcf7ce94fa2d
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built keybert sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers, keybert
# Successfully installed keybert-0.8.3 sentence-transformers-2.2.2 sentencepiece-0.1.99
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 30.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.16.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.20.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039290 sha256=cb4fa403c6ade7397fdec0a9017b39de35008bba4b834971d54ab5946db0b1e1
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=8f0a3bac87411994d059288a91483f3a962146e4a0929cfe3144e6fcb7cb942e
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan umap-learn
# Installing collected packages: cython, pynndescent, hdbscan, umap-learn, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.7
#     Uninstalling Cython-3.0.7:
#       Successfully uninstalled Cython-3.0.7
# Successfully installed bertopic-0.16.0 cython-0.29.37 hdbscan-0.8.33 pynndescent-0.5.11 umap-learn-0.5.5
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)

# %% [markdown]
# ### 3. 설치된 모듈 및 라이브러리 불러오기

# %%
# 데이터 처리
import pandas as pd
import numpy as np

# 진행 과정 시각화
from tqdm.notebook import tqdm

# 한국어 형태소 분석기
from kiwipiepy import Kiwi
from konlpy.tag import *

# 모델
from keybert import KeyBERT
from bertopic import BERTopic

# 임베딩 모델
from transformers import AutoModel, AutoTokenizer
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ### 4. 분석할 데이터 불러오기
#
# - 소아암 생존자 Question 데이터셋

# %%
#  데이터 읽기
df = pd.read_excel('data1.xlsx')

# 데이터 첫 5행 읽기
df.head()

# 마지막 5행 읽기
# df.tail()
# Out:
#                                 question
# 0                피로도에 따른 쉼을 어떻게 갖고 계십니까?
# 1  암완치자이기 때문에 일반인과 다른 생활 모습은 어떤 것이 있습니까?
# 2                 완치자들의 모임을 소개받을 수 있을까요?
# 3                    진학관련 상담을 받을 수 있을까요?
# 4          동일한 병명으로 치료받은 완치자를 만날 수 있을까요?

# %%
# 데이터 확인

# 데이터 컬럼명 확인
print(df.columns)

# 데이터 정보 확인
df.info()

# 데이터 길이 확인
len(df)
# Out:
# Index(['question'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  500 non-null    object
# dtypes: object(1)
# memory usage: 4.0+ KB
# 500

# %% [markdown]
# ### 5. 형태소 분석
#
# - konlpy: https://konlpy.org/ko/v0.4.3/api/konlpy.tag/
# - kiwi: https://github.com/bab2min/Kiwi

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 형태소 분석기 이름 지정
# Konlpy
hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()

# kiwi
kiwi = Kiwi()

# %%
text = '소아암 생존자를 위한 챗봇 개발'

# 형태소 분석기명.함수명(분석하고자 하는 텍스트)
print(hannanum.analyze(text))
print(hannanum.morphs(text))
print(hannanum.nouns(text))
print(hannanum.pos(text))
# Out:
# [[[('소아', 'ncn'), ('암', 'ncn')]], [[('생존자', 'ncn'), ('를', 'jco')], [('생존', 'ncpa'), ('자', 'ncn'), ('를', 'jco')]], [[('위하', 'pvg'), ('ㄴ', 'etm')]], [[('챗봇', 'ncn')], [('챗봇', 'nqq')]], [[('개발', 'ncn')], [('개발', 'ncpa')]]]
# ['소아암', '생존자', '를', '위하', 'ㄴ', '챗봇', '개발']
# ['소아암', '생존자', '챗봇', '개발']
# [('소아암', 'N'), ('생존자', 'N'), ('를', 'J'), ('위하', 'P'), ('ㄴ', 'E'), ('챗봇', 'N'), ('개발', 'N')]

# %%
kiwi.analyze(text)
# Out:
# [([Token(form='소아', tag='NNG', start=0, len=2),
#    Token(form='암', tag='NNG', start=2, len=1),
#    Token(form='생존자', tag='NNG', start=4, len=3),
#    Token(form='를', tag='JKO', start=7, len=1),
#    Token(form='위하', tag='VV', start=9, len=2),
#    Token(form='ᆫ', tag='ETM', start=10, len=1),
#    Token(form='챗봇', tag='NNG', start=12, len=2),
#    Token(form='개발', tag='NNG', start=15, len=2)],
#   -87.31249237060547)]

# %%
# NNG: 일반명사, NNP: 고유명사, NNB: 의존명사, NR: 수사, NP: 대명사

def noun_extractor(text):
  """"
  명사 형태만 추출
  """
  nouns = [] # list

  result = kiwi.analyze(text)
  for token, pos, _, _ in result[0][0]:
    # if len(token) != 1 and pos.startswith('N'): # 한글자가 아닌 명사형태만 추출
    if pos.startswith('N'): # 한글자가 아닌 명사형태만 추출
      nouns.append(token) # list에 해당 단어를 더해줌

  return nouns

# %%
noun_extractor(text)
# Out:
# ['소아', '암', '생존자', '챗봇', '개발']

# %%
# question에 대해서만 분석 진행

my_df = df['question'].tolist() # Series to List
my_docs = ' '.join(my_df) # List to String
my_docs
# Out:
# '피로도에 따른 쉼을 어떻게 갖고 계십니까? 암완치자이기 때문에 일반인과 다른 생활 모습은 어떤 것이 있습니까? 완치자들의 모임을 소개받을 수 있을까요? 진학관련 상담을 받을 수 있을까요? 동일한 병명으로 치료받은 완치자를 만날 수 있을까요? 사회적응을 한 완치자와 맨토맨티 관계를 형성할 수 있을까요?  환자 가정에 형제자매들의 케어에 대해 물어볼 수 있을까요? 보호자의 케어는 어떻게 되어야 할까요? 치료 후 운동은 어떻게 하나요? 후유증 관리는 어떻게 진행되나요? 빠진 머리카락은 언제쯤 날까요? 예전처럼 똑같이 머리가 다시 자라나요? 다시 일상생활로 돌아갈수 있나요? 체력은 문제 없을까요? 마스크는 계속 써야 하나요? 직장을 구할때 병력을 말해야 할까요? 숨겨야 할까요? 언제까지 음식을 제한하면서 먹어야 하나요? 일상생활하면서 음식을 자유롭게 먹을수 있을까요? 헌혈을 할수 있나요? 나중에 아이를 낳을수 있을까요? 소아암으로 인해 다른 암에 걸릴 확률이 높아지나요? 이성을 사기게 되거나 결혼를 할때 말해야 하나요? 직장생활을 하거나 학교에 갈때 체력적으로 문제가 없나요? 치료가 끝난 후 발생되는 건강상의 문제에대한 해결방법 면접시 소아암 앓았던 과거 밝히는지 진로는 어느쪽으로 가는지 취업시 고려하는사항 건강관리 방법 후유증으로 어떤걸 앓고있는지 사회생활에 소아암 관련하여 문제 없는지 직장내에서 소아암 이력 밝히는지 결혼에 대한 생각 결혼했다면 자녀에 대한 생각 치료 중 먹어도 되는 음식, 안되는 음식, 이것을 먹어도 될까요? 연애나 결혼시 나의 병력을 어떻게 언제 공개해야하나? 학교 활동을 할 때 안되는 영역(체육, 캠프 등) 검정고시를 보고 학교에 가도 될까요? 학교 진학시 배려받을 수 있는 부분이 있을까요? 보험 가입시 어떻게 선택해야하는 것이 좋은가요? 기초 면역력을 올리는 생활방법 이 궁금합니다. 체력이 아니라 바이러스에 취약하기 때문에 궁금합니다. 해외여행시 주의해야할 점이 궁금합니다.  구토 증세를 완화할 수 있는 방법이 궁금합니다. 암 환자는 장기기증이나 조혈모기증을 못하나요? 암환자가 암 보험에 가입할 수 있나요? 취업이나 진학시 밝히지 않아도 괜찮나요? 해외파견이나 출장시 불이익이 있는 것 같으면 어떻게 대응할 수 있을까요? 학교 복귀 시 학우들과 잘 지내려면 어떻게 해야할까요? 항암치료로 인하여 또래 친구들보다 늦게 입학 또는 한 학년 아래로 다니게 될 때 불편함은 없었는지 궁금합니다. 항암치료 때 식이요법은 어떻게 해야할까요? 다른 사람들에게 항암치료를 받았다고 이야기를 해야할까요? 완치 후 남자의 경우, 군면제를 받게 되는데 친구들에게 알리게 될 경우 항암치료를 했었다는게 두렵습니다. 어떻게 해야할까요? 항암치료를 할 때 안좋게 될까봐 걱정이 많은데 어떻게 해야 할까요? 항암치료를 했었던 과거력이 취업할 때 불이익이  있을까요? 이성교제를 할 경우, 상대방에게 솔직하게 말해야할지 고민입니다. 항암치료 후 체력관리는 어떻게 하나요? 항암치료 때 부모님이랑 갈등이 있을 때 어떻게 해결하나요? 완치후 학교로 돌아갔을때 친구들에게 소아암에 대해 밝혀야 하나요? 친구들에게 소아암에 대해 어떻게 소개를 하면 좋을까요 학습적으로 부족한 부분은 어떻게 해결하면 좋을까요? 후유증이 발생하였을때 같은치료를 받고 있는 사례있는지 궁금합니다 후유증에 대해  실망감과 우울감을 위로해줄 방법이 있을까요? 완치후 인간관계을  어떻게 하였는지 궁금합니다 외모적으로 보이는 모습에 대해 사람들에 대한 시선들을 어떻게 극복하였는지 궁금합니다 완치는 하였지만 후유증을 남았을 경우 경제적 지원이 가능한가요? 완치후  다른 경험자들과 만나는 기회가 있나요? 사회생활을 할때 소아암에 걸렸다는 사실을 말해야 하나요? 취업시 소아암 경험자였음을 밝혀야 할까요? 암 치료가 끝난 후 학교로 복귀할 때 친구들과 다시 가까워질 수 있는 방법이 있을까요? 치료가 종결된 후 학교로 복귀할 때 다시 적응하는 데 어려움을 겪을까 무서워요 암 치료 과정에서 겪었던 힘든 마음을 위로할 방법이 있을까요? 힘든 치료과정으로 인해 생각해보기 힘들었던 진로를 결정하는 데 도움이 될 만한 활동 등에는 무엇이 있을까요? 대입을 앞두고 치료를 종결한 암 경험자를 위한 입시 프로그램이 있나요? 대학 면접에서 암 경험자임을 밝혀도 괜찮을까요? 치료 기간 중 학교 수업에 재대로 참여하지 못해 걱정이 돼요 치료가 끝난 후 학교로 복귀할 때 친구들에게 어느정도 선까지 밝히는게 좋을까요? 학교 수업에 모두 참여하기 위해 체력을 기르고 싶은데 어떤 운동을 하는게 도움이 될까요? 취업할 때 소아암 병력을 꼭 말해야 할까요? 저만 건강염려증이 생기는건가요? 술, 담배를 못하는데 사회생활을 할 때 이런것들이 없어도 괜찮나요? 병이 언제든지 다시 시작될 수도 있다는 불안감이 드는데 이럴땐 어떻게 해야 하나요? 다른 암이 또 생기지는 않을까요? 내가 암환자였다고 말하면 날 보는 시선들이 달라질까요? 내가 도움 받을 수 있는 곳이 있나요?(상담, 복지 등) 학교에 복귀한다면 친구들에게 암환자라는걸 밝혀야할까요? 치료가 끝나면 보통 무엇을 하나요? 일상 속에 다시 돌아갈 때 어려운 점은 없었나요? 치료 후 외모가 다시 돌아올 수 있을까요? 다른 사람들의 치료 경과가 어떨까요? 앞으로 건강관리를 어떻게 하면 좋을까요? 학교생활에 어떻게하면 잘 적응할 수 있을까요? 앞으로의 진로가 막막해요 소아암에 대한 사회적 인식이 어떨지 궁금해요 소아암 경험자들의 커뮤니티가 있을까요? 경험자들을 위해 봉사를 하고싶은데 어떻게 할 수 있을까요? 학업에 공백이 생겨 어떻게 따라가야할지 막막해요 활용할 수 있는 입시 전형이 궁금해요 심리적으로 불안한데 어떻게할지 모르겠어요 심리상담을 받고싶어요 금전적인 어려움이 있어요 취업면접을볼때 내가 암에걸렸던게 문제가될까요? 재발 불안감을 떨치는 방법이 있나요? 치료후 조심해야하는음식이나 멀리해야하는 음식이 있나요? 남들의 시선을 어떻게 극복할수있을까요? 치료후 찾아오는 후유증을 어떻게 극복할수있을까요? 술을 멀리해야 하나요? 담배를 멀리해야 하나요? 치료후 오는 우울증은 어떻게 극복하나요? 치료후 변한 외모때문에 자신감이 떨어지는데 어떻게 이겨낼수있을까요? 결혼후 아이에게 유전이될 가능성이 있나요? 제 병력을 여자친구에게 밝히는 게 좋을까요? 암 치료 때 힘들었던 마음을 위로할 방법이 있나요? 취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요? 대인관계가 어려운데 어떻게 하면 좋을까요 주변 시선들이 부담스럽고 힘든데 그럴땐 뭐라고 해야할지 모르겠어요 치료 종결 후 대학을 다니려니 너무 막막한데 어떻하면 극복할 수 있을까요? 다른 소아암 친구들은 잘하는게 많고 하고싶은게 많은데 그런 친구들을 보니 생각이 많아져요 어떡하면 좋을지 모르겠어요 병원입원 했을 때 시간 빨리 보내는 방법이 무엇이 있을까요? 치료 종결 후 진로 고민이 너무 되는데 무얼 어떻게 하면 될지 모르겠어요 치료로 인해 집에서 지내는 시간이 많은데 무얼 하면 보내면 좋을까요? 결혼을 생각중인 남자친구에게 병력이 있음을 이야기 하는게 좋을까요? (불임 가능성) 건강염려증이 나아지지 않는데 해결방법이 있을까요? 후유증이나 트라우마는 어떻게 해결할 수 있을까요 상처받았던 마음이 쉽게 회복되지 않을때는 어떻게 하는게 좋을까요? 동일한 질병을 겪었던 환우들이 어떻게 살고 있는지 궁금합니다. 친구들에게 병력을 고백해야 할까요? 병력자로서 받을 수 있는 혜택이나 자조모임은 뭐가 있을까요? 병력의 경험이 유전이 되지는 않나요? 저와 같은 아픔을 겪었던 환자들과 소통하려면 어떻게 하죠? 면접에서 아팠던 사실을 말하는게 좋을까요? 취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요? 생리는 돌아오지 않는 것일까요? 다음에 다른 암에 걸릴 확률이 비교적 높을까요? 회복 후 다들 어떻게 살고 있나요? 체력이 약한데 투병경험 때문에 그런걸까요? 왜 제가 아파야만 했을까요? 다시 아플까봐 겁이 나요 소아암을 이겨낸 유명인은 누가 있나요? 암에 걸려 치료받느라 남들보다 몇 년이나 늦어진게 아쉬워요 다시 암에 안걸릴려면 어떻게 하는 것이 좋을까요? 항암치료후 머리가 잘 자라나요? 머리카락이 너무 얇은데 언제 예전머리로 돌아갈까요 치료 종결 ...

# %%
# text에서 명사만 추출하여 저장
df_nouns = noun_extractor(my_docs)
# df_nouns

# list to text 형태로 변경
noun_docs = ' '.join(df_nouns)
noun_docs
# Out:
# '피로도 쉼 완치자 때문 일반인 생활 모습 것 완치자 모임 소개 수 진학 관련 상담 수 병명 치료 완치자 수 사회 적응 완치자 맨토맨티 관계 형성 수 환자 가정 형제 자매 케어 수 보호자 케어 치료 후 운동 후유증 관리 진행 머리카락 언제쯤 나 예전 머리 일상생활 수 체력 문제 마스크 직장 때 병력 말 언제 음식 제한 일상 생활 음식 자유 수 헌혈 수 나중 아이 수 소아 암 암 확률 이성 사기 결혼 르 때 말 직장 생활 학교 때 체력 문제 치료 후 발생 건강 문제 해결 방법 면 접시 소아 암 과거 진로 쪽 취업 시 고려 사항 건강 관리 방법 후유증 거 사회생활 소아 암 관련 문제 직장 내 소아 암 이력 결혼 생각 결혼 자녀 생각 치료 중 음식 음식 이것 연애 결혼 시 나 병력 공개 학교 활동 때 영역 체육 캠프 등 검정고시 학교 학교 진학 시 배려 수 부분 보험 가입 시 선택 것 기초 면역력 생활 방법 체력 바이러스 취약 때문 해외 여행 시 주의 점 구토 증세 완화 수 방법 암 환자 장기 기증 조혈 모 기증 암 환자 암 보험 가입 수 취업 진학 시 해외 파견 출장 시 이익 것 대응 수 학교 복귀 시 학우 항암 치료 또래 친구 입학 학년 아래 때 불편 항암 치료 때 식이요법 사람 항암 치료 이야기 완치 후 남자 경우 군 면제 친구 경우 항암 치료 것 항암 치료 때 걱정 항암 치료 과거 취업 때 이익 이성 교제 경우 상대방 말 고민 항암 치료 후 체력 관리 항암 치료 때 부모 갈등 때 해결 완치 후 학교 때 친구 소아 암 친구 소아 암 소개 학습 부족 부분 해결 후유증 발생 때 치료 사례 후유증 실망감 우울감 위로 방법 완치 후 인간관계 을 외모 모습 사람 시선 극복 완치 후유증 경우 경제 지원 가능 완치 후 경험자 기회 사회생활 때 소아 암 사실 말 취업 시 소아 암 경험자 암 치료 후 학교 복귀 때 친구 수 방법 치료 종결 후 학교 복귀 때 적응 데 어려움 암 치료 과정 힘 마음 위로 방법 힘 치료 과정 생각 진로 결정 데 도움 만 활동 등 무엇 대입 치료 종결 암 경험자 입시 프로그램 대학 면접 암 경험자 치료 기간 중 학교 수업 재 참여 걱정 치료 후 학교 복귀 때 친구 정도 선 것 학교 수업 참여 체력 운동 것 도움 취업 때 소아 암 병력 말 저 건강염려증 거 술 담배 사회 생활 때 것 병 언제 시작 수 불안감 때 암 나 암 환자 말 나 시선 나 도움 수 곳 상담 복지 등 학교 복귀 친구 암 환자 거 치료 무엇 일상 속 때 점 치료 후 외모 수 사람 치료 경과 앞 건강 관리 학교생활 적응 수 앞 진로 소아 암 사회 인식 소아 암 경험 커뮤니티 경험자 봉사 수 학업 공백 활용 수 입시 전형 심리 불안 심리 상담 금전 어려움 취업 면접 때 나 암 것 문제 재발 불안감 방법 치료 후 조심 음식 음식 남 시선 극복 수 치료 후 후유증 극복 수 술 담배 치료 후 우울증 극복 치료 후 외모 때문 자신감 수 결혼 후 아이 유전 가능 저 병력 여자 친구 것 암 치료 때 마음 위로 방법 취업 면접 때 나 암 것 말 대인 관계 주변 시선 부담 때 뭐 치료 종결 후 대학 극복 수 소아 친구 것 것 친구 생각 병원 입원 때 시간 방법 무엇 치료 종결 후 진로 고민 무어 치료 집 시간 무어 결혼 생각 중 남자 친구 병력 이야기 것 불임 가능 건강염려증 해결 방법 후유증 트라우마 해결 수 상처 마음 회복 때 것 동일 질병 환우 친구 병력 고백 병력 수 혜택 자조 모임 뭐 병력 경험 유전 저 아픔 환자 소통 면접 사실 말 것 취업 면접 때 나 암 것 말 생리 것 다음 암 확률 비교 회복 후 체력 투병 경험 때문 거 저 겁 소아 암 유명인 누구 암 치료 남 년 것 암 것 항암 치료 후 머리 머리카락 예전 머리 치료 종결 후 놀이기구 치료 종결 후 해외 여행 면접 때 암 거 말 모자 사람 것 치료 후 피부 건조 치료 후 것 다리 것 치료 후 냄새 머리 자신감 암 치료 때 점 암 투병 중 친구 말 소원 저 저 병 사람 암 원인 뭐 암 거 유전 항암 때 음식 항암 종류 음식 항암 치료 시간 남 몸 상태 건강 걱정 주의 합병증 왼쪽 난소 절제술 몸 영향 저 수 복지 정책 서비스 일 몸 걱정 공부 운동 부담 사람 소아 암 생각 병 건강 도움 만 정보 취업 면접 실습 면접 때 나 암 것 말 암 일반 사람 수 만약 저 스트레스 소아 암 발 책임 누구 저 일반 사람 일 저 직업 직업 생각 대학교 사이버 대학 취업 실습 면접 일반 사람 소아 암 경험 누구 가능 취업 것 재발 시 치료 포기 살 수 휴유증 실습 취업 가능 소아 암 경험자 결혼 아이 머리 휴유증 것 병원 생활 친구 것 힘 방법 건강 관리 학업 사람 소아 암 직업 추천 쥴수 것 마음 힘 때 어떻개 하나 체력 보충 나 사랑 방법 자존감 방법 방법 결혼 자식 것 문제 직장 면접 시 암 치료 경험 말 백혈병 혈액 종양 쪽 완치 판정 의미 거 언제 완치 생각 수 용량 항암 치료 합병증 예방 차원 내분비 유방 갑상선 쪽 정기 점검 중 언제 병원 암 치료 합병증 키 정도 체력 문제 걱정 직업 것 백혈병 년 정 기피 검사 언제 정기 검사 필요 거 남자 친구 때 병력 말 대학 생활 때 동아리 활동 과거 병력 자존감 수 추천 현재 백혈병 치료 중 사람 백혈병 완치 설명 키 덩치 때문 남자 친구 엄두 자신 극복 수 방법 암 치료 과정 힘 점 티비 것 의지 사람 부작용 극복 군대 수 인생 설계 것 누구 모임 동호회 장애 등급 수 주변 사람 이상 시선 수 사회 활동 혜택 암 치료 진행 상황 설명 의사 선생 프로필 병원 암 치료 경력 애인 것 직장 채용 건강 검진 때 암 치료 경험 이익 암 치료 뒤 조심 부분 환자 거 사람 수도 지방 암 환자 관련 자조 집단 저 암 미래 자녀 유전 거 어린아이 암 설명 환자 가족 정신 간호 복지 제공 수 치료 종결 후 년 이상 검사 암 치료 부작용 암 환자 도움 만 책 이성 친구 암 거 직장 머 접시 암 거 사회 친구 암 진단 거 운동 동호회 거 결혼 거 직장 수 자녀 수 음식 것 건강 중요 거 마음 명상 암 정복 약 개발 자녀 유전 암 치료 것 친구 선생 말 것 치료 친구 이야기 때 항암 치료 경우 나 아이 유전 항암 치료 뒤 기억력 예전 거 언제 병원 거 나 항암 치료 나중 군대 때 지장 항암 치료 것 나중 나 취업 때 이익 뇌종양 복싱 운동 것 지장 뇌종양 진단 항암 치료 머리 머리 충격 종양 영향 항암 치료 후 재발 경우 항암 치료 효과 전 항암 치료 수 뇌종양 거 관련 취업 면접 때 나 암 것 말 암 치료 후 사회 복귀 때 저 병력 애인 친구 것 치료 종결 일상생활 복귀 수 치료 종결 후 남 대학 입학 수 때 치료 세상 힘 때 저 앞 수 것 조금 번 재발 저 삶 거 친구 저 안 벽 소아 암 경험 취업 승진 시 걸림돌 통계 소아 암 경험자 사람 기대 수명 치료 종결 후 중장년 때 소아 암 합병증 발생 수 소아 암 경험 추후 출산 영향 정자 난임 기형아 등 소아 암 경험자 결혼 스토리 치료 종결 후 소아 암 경험자 커뮤니티 계속 참여 것 사회 커뮤니티 집중 것 소아 암 경험자 소아 경험 후 자신 가치관 꿈 소아 암 경험자 사회 일 소아 암 경험자 사회 진출 때 어려움 점 무엇 소아 암 경험자 고민 무엇 사회 생활 시작 친구 관계 회복 자신감 결여 가족 마음 치료 방법 공부 두려움 극복 취업 방법 재발 극복 도움 필요 사람 소통 방법 미래 설계 도전 시간 필요 치료 후 일상생활 복귀 방법 치료 이후 건강 관리 사회생활 기준 무엇 정보 공유 자립 경험 공유 종결 후 가족 소통 학교 복귀 후 친구 소통 항암 동안 힘 때 마음 방법 환경 참여 때 병력 형제 소통 개선 부진 공부 걱정 군대 사람 시선 부담 재발 두려움 체력 수 암 완치 가능 암 치료 방법 구체 암 거 암 치료 중 위로 것 치료 중 수 것 도움 만 것 치료 완치 후 버킷 리스트 암 치료 후 현실 복귀 때 마음가짐 것 완치 후 재발 방지 노력 부분 남자 경우 암 진단 치료 내용 사회 혜택 병력 나 인생 흠 사회 말 수 멘탈 관리 방법 암 치료 완료 추후 부작용 장애 때 제도 혜택 지침서 저 병력 남자 친구 것 취업 때 저 병력 회사 것 치료 방사선 치료 머리카락 저 가발 것 사람 것 암 환자 저 수 지원 치료 몸 흉터 부작용 이거  ...

# %% [markdown]
# ### 6. 키워드 분석
#
# - Keybert: https://github.com/MaartenGr/KeyBERT
# - Keybert 참고문헌2: https://wikidocs.net/159467
# - sbert: https://www.sbert.net/docs/pretrained_models.html

# %% [markdown]
# **Keybert 모델 parameter**
#
# *   keyphrases_ngram_range: 키워드/키구문의 길이 지정
# *   stop_words: 불용어 지정
# *   highlight: 문서 내에서 키워드 highlight (True/False)
# *   use_maxsum: 결과 다양성을 위한 파라미터 (True/False)
# *   use_mmr: 결과 다양성을 위한 파라미터 (True/False)
# *   diverisity: 다양성 정도 (0~1)
# *   top_n: 최종 키워드 개수 설정

# %%
# 키워드 분석

sbert_model = "paraphrase-multilingual-mpnet-base-v2" #사전학습 모델
# model = AutoModel.from_pretrained("klue/bert-base")

keymodel = KeyBERT(sbert_model)
# Out:
# .gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.10k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
# my_docs: 기본 데이터셋 / noun_docs: 명사 형태만 추출한 데이터셋
key_nouns_v1 = keymodel.extract_keywords(noun_docs, keyphrase_ngram_range=(1,1), top_n=20)
key_nouns_v1
# Out:
# [('일상생활', 0.5831),
#  ('일상', 0.5758),
#  ('케어', 0.5743),
#  ('상담', 0.565),
#  ('피로도', 0.5349),
#  ('진학', 0.5288),
#  ('간호', 0.5244),
#  ('건강', 0.5234),
#  ('진료', 0.516),
#  ('치료자가', 0.5156),
#  ('피로감', 0.5146),
#  ('극복', 0.5146),
#  ('건강염려증', 0.5137),
#  ('치료', 0.5119),
#  ('사회생활', 0.5094),
#  ('자조', 0.4888),
#  ('동호회', 0.488),
#  ('휴유증', 0.4849),
#  ('출장', 0.4844),
#  ('일반인', 0.4839)]

# %%
key_nouns_v2 = keymodel.extract_keywords(my_docs, keyphrase_ngram_range=(1,3), use_maxsum=True, diversity=1, top_n=10)
key_nouns_v2
# Out:
# [('치료이후 관리는 어떻게', 0.6632),
#  ('암치료의 고통에서 벗어날수있는', 0.6651),
#  ('직장면접시 암치료경험을', 0.6675),
#  ('암환자 가족은 어떠한', 0.6712),
#  ('사회생활을 할때 소아암에', 0.6731),
#  ('암을 이겨내고 일상생활', 0.6841),
#  ('직장면접시 암치료경험을 말해야할까요', 0.6869),
#  ('암에 걸리면 가족이나', 0.6899),
#  ('극복하셨나요 치료 건강관리는', 0.6981),
#  ('암치료자들의 사회생활이 궁금해요', 0.7355)]

# %% [markdown]
# #### Option - 시각화 (WordCloud)
#
# - 단어 색상 참조: https://matplotlib.org/stable/gallery/color/colormap_reference.html

# %%
# !pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from WordCloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from WordCloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from WordCloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WordCloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WordCloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WordCloud) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WordCloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WordCloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WordCloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)

# %%
# 한국어 폰트 설치
# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath='/user/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font=fm.FontProperties(fname=fontpath,size=9)
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
from PIL import Image
masking_image = np.array(Image.open("cloud.png"))

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud=WordCloud(font_path=fontpath,
                    background_color='white', # white / black
                    # max_words = 100,
                    # max_font_size = 100,
                    colormap = 'coolwarm',
                    mask = masking_image
                    )
wordcloud.generate(noun_docs)

fig=plt.figure(figsize=(10,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# 이미지 저장
# fig.savefig('wordcloud_result.png')

# %% [markdown]
# ### 7. 토픽 모델링 (Topic Modeling)

# %% [markdown]
# #### 1) Clustering - DBSCAN

# %%
noun_list = []

for question in tqdm(my_df):
  words = noun_extractor(question)
  noun_list.append(words)


dbscan_df = pd.DataFrame() # 데이터 프레임 생성
dbscan_df['question'] = my_df
dbscan_df['nouns'] = noun_list

dbscan_df.head()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#                                 question                      nouns
# 0                피로도에 따른 쉼을 어떻게 갖고 계십니까?                   [피로도, 쉼]
# 1  암완치자이기 때문에 일반인과 다른 생활 모습은 어떤 것이 있습니까?  [완치자, 때문, 일반인, 생활, 모습, 것]
# 2                 완치자들의 모임을 소개받을 수 있을까요?           [완치자, 모임, 소개, 수]
# 3                    진학관련 상담을 받을 수 있을까요?            [진학, 관련, 상담, 수]
# 4          동일한 병명으로 치료받은 완치자를 만날 수 있을까요?           [병명, 치료, 완치자, 수]

# %%
data = [" ".join(word) for word in dbscan_df['nouns']]
data
# Out:
# ['피로도 쉼',
#  '완치자 때문 일반인 생활 모습 것',
#  '완치자 모임 소개 수',
#  '진학 관련 상담 수',
#  '병명 치료 완치자 수',
#  '사회 적응 완치자 맨토맨티 관계 형성 수',
#  '환자 가정 형제 자매 케어 수',
#  '보호자 케어',
#  '치료 후 운동',
#  '후유증 관리 진행',
#  '머리카락 언제쯤 나 예전 머리',
#  '일상생활 수 체력 문제',
#  '마스크',
#  '직장 때 병력 말',
#  '언제 음식 제한 일상 생활 음식 자유 수',
#  '헌혈 수',
#  '나중 아이 수',
#  '소아 암 암 확률',
#  '이성 사기 결혼 르 때 말',
#  '직장 생활 학교 때 체력 문제',
#  '치료 후 발생 건강 문제 해결 방법',
#  '면접 시 소아 암 과거',
#  '진로 쪽',
#  '취업 시 고려 사항',
#  '건강관리 방법',
#  '후유증 거',
#  '사회생활 소아 암 관련 문제 지',
#  '직장 내 소아 암 이력',
#  '결혼 생각',
#  '결혼 자녀 생각',
#  '치료 중 음식 음식 이것',
#  '연애 결혼 시 나 병력 공개',
#  '학교 활동 때 영역 체육 캠프 등',
#  '검정고시 학교',
#  '학교 진학 시 배려 수 부분',
#  '보험 가입 시 선택 것',
#  '기초 면역력 생활 방법 체력 바이러스 취약 때문',
#  '해외 여행 시 주의 점',
#  '구토 증세 완화 수 방법',
#  '암 환자 장기 기증 조혈 모 기증',
#  '암 환자 암 보험 가입 수',
#  '취업 진학 시',
#  '해외 파견 출장 시 이익 것 대응 수',
#  '학교 복귀 시 학우',
#  '항암 치료 또래 친구 입학 학년 아래 때 불편',
#  '항암 치료 때 식이요법',
#  '사람 항암 치료 이야기',
#  '완치 후 남자 경우 군 면제 친구 경우 항암 치료 것',
#  '항암 치료 때 걱정',
#  '항암 치료 과거 취업 때 이익',
#  '이성 교제 경우 상대방 말 고민',
#  '항암 치료 후 체력 관리',
#  '항암 치료 때 부모 갈등 때 해결',
#  '완치 후 학교 때 친구 소아 암',
#  '친구 소아 암 소개',
#  '학습 부족 부분 해결',
#  '후유증 발생 때 치료 사례',
#  '후유증 실망감 우울감 위로 방법',
#  '완치 후 인간관계 을',
#  '외모 모습 사람 시선 극복',
#  '완치 후유증 경우 경제 지원 가능',
#  '완치 후 경험자 기회',
#  '사회생활 때 소아 암 사실 말',
#  '취업 시 소아 암 경험자',
#  '암 치료 후 학교 복귀 때 친구 수 방법',
#  '치료 종결 후 학교 복귀 때 적응 데 어려움',
#  '암 치료 과정 힘 마음 위로 방법',
#  '힘 치료 과정 생각 진로 결정 데 도움 만 활동 등 무엇',
#  '대입 치료 종결 암 경험자 입시 프로그램',
#  '대학 면접 암 경험자',
#  '치료 기간 중 학교 수업 재 참여 걱정',
#  '치료 후 학교 복귀 때 친구 정도 선 것',
#  '학교 수업 참여 체력 운동 것 도움',
#  '취업 때 소아 암 병력 말',
#  '저 건강염려증 거',
#  '술 담배 사회 생활 때 것',
#  '병 언제 시작 수 불안감 때',
#  '암',
#  '나 암 환자 말 나 시선',
#  '나 도움 수 곳 상담 복지 등',
#  '학교 복귀 친구 암 환자 거',
#  '치료 무엇',
#  '일상 속 때 점',
#  '치료 후 외모 수',
#  '사람 치료 경과',
#  '앞 건강 관리',
#  '학교생활 적응 수',
#  '앞 진로',
#  '소아 암 사회 인식',
#  '소아 암 경험 커뮤니티',
#  '경험자 봉사 수',
#  '학업 공백',
#  '활용 수 입시 전형',
#  '심리 불안',
#  '심리 상담',
#  '금전 어려움',
#  '취업 면접 때 나 암 것 문제',
#  '재발 불안감 방법',
#  '치료 후 조심 음식 음식',
#  '남 시선 극복 수',
#  '치료 후 후유증 극복 수',
#  '술',
#  '담배',
#  '치료 후 우울증 극복',
#  '치료 후 외모 때문 자신감 수',
#  '결혼 후 아이 유전 가능',
#  '저 병력 여자 친구 것',
#  '암 치료 때 마음 위로 방법',
#  '취업 면접 때 나 암 것 말',
#  '대인 관계',
#  '주변 시선 부담 때 뭐',
#  '치료 종결 후 대학 극복 수',
#  '소아 친구 것 것 친구 생각',
#  '병원 입원 때 시간 방법 무엇',
#  '치료 종결 후 진로 고민 무어',
#  '치료 집 시간 무어',
#  '결혼 생각 중 남자 친구 병력 이야기 것 불임 가능',
#  '건강염려증 해결 방법',
#  '후유증 트라우마 해결 수',
#  '상처 마음 회복 때 것',
#  '동일 질병 환우',
#  '친구 병력 고백',
#  '병력 수 혜택 자조 모임 뭐',
#  '병력 경험 유전',
#  '저 아픔 환자 소통',
#  '면접 사실 말 것',
#  '취업 면접 때 나 암 것 말',
#  '생리 것',
#  '다음 암 확률 비교',
#  '회복 후',
#  '체력 투병 경험 때문 거',
#  '저',
#  '겁',
#  '소아 암 유명인 누구',
#  '암 치료 남 년 것',
#  '암 것',
#  '항암 치료 후 머리',
#  '머리카락 예전 머리',
#  '치료 종결 후 놀이기구',
#  '치료 종결 후 해외 여행',
#  '면접 때 암 거 말',
#  '모자 사람 것',
#  '치료 후 피부 건조',
#  '치료 후 것 다리 것',
#  '치료 후 냄새',
#  '머리 자신감',
#  '암 치료 때 점',
#  '암 투병 중 친구 말',
#  '소원',
#  '저',
#  '저 병 사람',
#  '암 원인 뭐',
#  '암 거',
#  '유전',
#  '항암 때 음식',
#  '항암 종류',
#  '음식',
#  '항암 치료 시간 남 몸 상태',
#  '건강 걱정',
#  '주의 합병증',
#  '왼쪽 난소 절제술 몸 영향',
#  '저 수 복지 정책 서비스',
#  '일 몸 걱정 공부 운동 부담',
#  '사람 소아 암 생각',
#  '병',
#  '건강 도움 만 정보',
#  '취업 면접 실습 면접 때 나 암 것 말',
#  '암 일반 사람 수',
#  '만약 저 스트레스 소아 암 발 책임 누구',
#  '저 일반 사람 일',
#  '저 직업 직업 생각',
#  '대학교 사이버 대학 취업 실습 면접 일반 사람 소아 암 경험 누구 가능',
#  '취업 것',
#  '재발 시 치료 포기 살 수',
#  '휴유증 실습 취업 가능',
#  '소아 암 경험자 결혼 아이 머리 휴유증 것',
#  '병원 생활 친구 것 힘 방법',
#  '건강 관리',
#  '학업',
#  '사람 소아 암',
#  '직업 추천 쥴수 것',
#  '마음 힘 때 어떻개 하나',
#  '체력 보충',
#  '나 사랑 방법',
#  '자존 방법',
#  '방법',
#  '결혼 자식 것 문제',
#  '직장 면접 시 암 치료 경험 말',
#  '백혈병 혈액 종양 쪽 완치 판정 의미 거 언제 완치 생각 수',
#  '용량 항암 치료 합병증 예방 차원 내분비 유방 갑상선 쪽 정기 점검 중 언제 병원',
#  '암 치료 합병증 키 정도 체력 문제 걱정 직업 것',
#  '백혈병 년 정 기피 검사 언제 정기 검사 필요 거',
#  '남자 친구 때 병력 말',
#  '대학 생활 때 동아리 활동 과거 병력 자존감 수 추천',
#  '현재 백혈병 치료 중 사람 백혈병 완치 설명',
#  '키 덩치 때문 남자 친구 엄두 자신 극복 수 방법',
#  '암 치료 과정 힘 점',
#  '티비 것',
#  '의지 사람',
#  '부작용 극복',
#  '군대 수',
#  '인생 설계 것 누구',
#  '모임 동호회',
#  '장애 등급 수',
#  '주변 사람 이상 시선 수',
#  '사회 활동 혜택',
#  '암 치료 진행 상황 설명 의사 선생 프로필 병원',
#  '암 치료 경력 애인 것',
#  '직장 채용 건강 검진 때 암 치료 경험 이익',
#  '암 치료 뒤 조심 부분',
#  '암 환자 거 사람',
#  '수도 지방 암 환자 관련 자조 집단',
#  '저 암 미래 자녀 유전 거',
#  '어린아이 암 설명',
#  '암 환자 가족 정신 간호 복지 제공 수',
#  '암 치료 종결 후 년 이상 검사',
#  '암 치료 부작용 암 환자 도움 만 책',
#  '이성 친구 암 거',
#  '직장 머 접시 암 거',
#  '사회 친구 암 진단 거',
#  '운동 동호회 거',
#  '결혼 거',
#  '직장 수',
#  '자녀 수',
#  '음식 것',
#  '건강 중요 거',
#  '마음 명상',
#  '암 정복',
#  '약 개발',
#  '자녀 유전',
#  '암 치료 것 친구 선생 말 것',
#  '치료 친구 이야기',
#  '때 항암 치료 경우 나 아이 유전',
#  '항암 치료 뒤 기억력 예전 거',
#  '언제 병원 거',
#  '나 항암 치료 나중 군대 때 지장',
#  '항암 치료 것 나중 나 취업 때 이익',
#  '뇌종양 복싱 운동 것 지장',
#  '뇌종양 진단 항암 치료 머리 머리 충격 종양 영향',
#  '항암 치료 후 재발 경우 항암 치료 효과 전 항암 치료 수',
#  '뇌종양 거 관련',
#  '취업 면접 때 나 암 것 말',
#  '암 치료 후 사회 복귀 때 저 병력 애인 친구 것',
#  '치료 종결 일상생활 복귀 수',
#  '치료 종결 후 남 대학 입학 수',
#  '때',
#  '치료 세상 힘 때',
#  '저 앞 수 것',
#  '조금',
#  '번 재발 저 삶 거',
#  '친구 저 안 벽',
#  '소아 암 경험 취업 승진 시 걸림돌',
#  '통계 소아 암 경험자 사람 기대 수명',
#  '치료 종결 후 중장년 때 소아 암 합병증 발생 수',
#  '소아 암 경험 추후 출산 영향 정자 난임 기형아 등',
#  '소아 암 경험자 결혼 스토리',
#  '치료 종결 후 소아 암 경험자 커뮤니티 계속 참여 것 사회 커뮤니티 집중 것',
#  '소아 암 경험자 소아 경험 후 자신 가치관 꿈',
#  '소아 암 경험자 사회 일',
#  '소아 암 경험자 사회 진출 때 어려움 점 무엇',
#  '소아 암 경험자 고민 무엇',
#  '사회 생활 시작',
#  '친구 관계 회복 자신감 결여',
#  '가족 마음 치료 방법',
#  '공부 두려움 극복',
#  '취업 방법',
#  '재발 극복',
#  '도움 필요 사람 소통 방법',
#  '미래 설계 도전 시간 필요',
#  '치료 후 일상생활 복귀 방법',
#  '치료 이후 건강 관리 사회생활 기준 무엇',
#  '정보 공유 자립 경험 공유',
#  '종결 후 가족 소통',
#  '학교 복귀 후 친구 소통',
#  '항암 동안 힘 때 마음 방법',
#  '환경 참여 때 병력',
#  '형제 소통 개선',
#  '부진 공부 걱정',
#  '군대',
#  '사람 시선 부담',
#  '재발 두려움',
#  '체력 수',
#  '완치 가능',
#  '암 치료 방법 구체',
#  '암 거',
#  '암 치료 중 위로 것',
#  '치료 중 수 것 도움 만 것',
#  '치료 완치 후 버킷리스트',
#  '암 치료 후 현실 복귀 때 마음가짐 것',
#  '완치 후 재발 방지 노력 부분',
#  '남자 경우 암 진단 치료 내용 사회 혜택',
#  '병력 나 인생 흠 사회 말 수 멘탈 관리 방법',
#  '암 치료 완료 추후 부작용 장애 때 제도 혜택 지침서',
#  '저 병력 남자 친구 것',
#  '취업 때 저 병력 회사 것',
#  '치료 방사선 치료 머리카락',
#  '저 가발 것 사람 것',
#  '암 환자 저 수 지원',
#  '치료 몸 흉터 부작용 이거 것',
#  '뇌 수술 인 사람 해결 방법',
#  '소아 암 경험자 아이 수',
#  '저 가발 거 남자 친구 경우 수 수 데',
#  '소아 암 경험자 삶 데 신체 정신 상처 재정 경우 소아 암 완치자 치료 종결 후 사회 복귀 환경 속 이 변화 필요 지원 필요',
#  '치료 중 공부',
#  '항암 치료 머리카락 지금 항암 치료 방사선 치료 머리카락',
#  '타지 치료 병원 수도 숙박 소독 숙박 시설',
#  '소아 암 치료 지원 것',
#  '연애 때 취업 때 상대방 나 예전 병명 말',
#  '완치 이후 병원 년',
#  '치료 이후 체력 관리 체력 관리 유산소 하체 운동 등',
#  '치료 때 힐링',
#  '치료 이후 관리',
#  '저 주변 치료 친구',
#  '부모 형제 위로 힘 수 지원 사업 무엇',
#  '인 서울 대학 진학 수 방법',
#  '대입 수시 사회 배려 전형 일반 전형 중 것 현실 유리',
#  '대학 엠티 오티 자연 술자리',
#  '암 치료 고등학교 자퇴 검정 고시 시험 것 온라인 수업 병원 학교 학교 적 생 기부 취득 것',
#  '암 기 기 기 기 기준 무엇 기 가능',
#  '암 후 치료 음식 구체 말',
#  '혈액암 우유 치즈 유제품 고기 섭취',
#  '암 치료 후 수술 치료 년 후 통계 합병증 암 발생',
#  '혈액암 유방암 난소암 골 종암 등 기수 최대 최소 생존 기간 말 시간 수',
#  '암 후 정상인 취업 대학 입학 차별 수',
#  '암 나 가족 미래 아이 유전 거',
#  '암 때',
#  '머리 머리 평균 시간 기간 말 숏 컷트 기간 단발 기간 어깨 기간 예 주 달 달',
#  '항암 치료 후 생리 갱년기 증상 증상 구체제으 말',
#  '항암 후 아이 수',
#  '나 자신 위로 방법',
#  '학교 친구 어디 여',
#  '친구 머리 놀림',
#  '나',
#  '나 모습',
#  '나 사람 부모 우리 부모 누구',
#  '사회 생활 너 때 뭐 뭐',
#  '항암 치료 약 때 치료',
#  '상사 과거 뭐 뭐',
#  '친구 말 것',
#  '마음 속 아픔 이해',
#  '전문의 연계',
#  '고통 공감 것',
#  '학교 선생 지인 친구 주변 사람 소아 암 경험자 사실 얘기 것',
#  '암 치료 후 학교 복귀 거 이유 무엇',
#  '치료 종결 후 일 일 무엇',
#  '나 자전거 생각 적',
#  '피 걱정 적',
#  '학교 생활 중 친구 소아 암 치료 과정 이야기 수',
#  '친구 체육 시간 놀이 때 소극 참여 적',
#  '소아 암 치료 꿈 치료 후 꿈',
#  '치료 종결 치료 중 소아 암 환아 경험 치료 경험 멘토 수 맀나요',
#  '소아 암 치료 후 수 운동 무엇',
#  '치료 중 죽음 것 생각 적',
#  '소아 암 가족 간 사랑 표현 방식 변화',
#  '소아 암 경험 중 나 것 감사 나 응원 사람 생각 적',
#  '병원 지역 소아 암 환아 복지 제도 사실',
#  '치료 종결 후 치료 환아 치료 경험',
#  '대학교 입학 시 주위 암 투병 사실',
#  '군대 것',
#  '과거 병력 기록 군대 군대 관련 질문 때 대답',
#  '연인 과거 병력 사실',
#  '연인 과거 병력 사실 고백 때 부정 반응',
#  '과거 집중 치료 친구 사회 것 느낌',
#  '치료 체력 시작 때 추천 수 활동',
#  '집중 치료 기간 중 학교 기본 진도 방법',
#  '집중 치료 기간 동안 음식',
#  '집중 치료 기간 동안 음식',
#  '머리 듯 두통 백혈병 후유증',
#  '친구 탈모 대응 대답',
#  '두통 타이레놀 머리 때 복용',
#  '항암 치료 이후 수업',
#  '간병 부모',
#  '항암 치료 이후 검정 고시 분',
#  '대학교 입시 전형 중 소아 암 완치자 관련 전형 대학 대학',
#  '시간 건강',
#  '학교',
#  '완치 이후 음식 생활 습관',
#  '기력 우울',
#  '병원 길',
#  '완치 이후 몸 상태 병원',
#  '완치자 모임 것',
#  '완치 이후 지원 수 것',
#  '군대 이유 말',
#  '지인 암 거',
#  '부모 건강 걱정 이제 걱정',
#  '암 수 걱정',
#  '위축 건강 염려 마음',
#  '피로감 평생 건강 관리',
#  '방사선 암 확률',
#  '여자 친구 나 병 거 언제 쯤 말',
#  '건강 검진 호르몬 검사 신경',
#  '년 이제 엠알아이 검사',
#  '저 건강 수',
#  '암 치료 후 이성 교제 언제 가능',
#  '조혈모세포 식후 숙주 반응 기간',
#  '완치 판정 후 재발 확률',
#  '암 치료 후 임신 가능 확률 가능',
#  '암 치료 생활 병 수',
#  '암 치료 평생 진료',
#  '암 치료 운동 건강 데 도움',
#  '암 치료 복지',
#  '암 치료 사회생활',
#  '급성 림프 구 백혈병 환자 모임 것',
#  '주변인 암 투병 사실',
#  '말 티 학교 투병 사실',
#  '암 치료 이후 예방 접종',
#  '혈액암 치료자 치료 후 예방 접종 것 이득',
#  '희귀 암 환자 소통 수 플랫폼',
#  '혈액암 환자 부작용 종류 사례',
#  '혈액암 환자 소아 이유',
#  '혈액암 환자 가족 환우',
#  '친구 혈액암 사실 때 것',
#  '혈액암 환자 것',
#  '학교 때 암 치료 경력 말',
#  '직장 생활 때 병력 말',
#  '생활 때 언제 정상인 생활 가능',
#  '재발 두려움',
#  '음식',
#  '이식 후 숙주 반응 언제',
#  '조심 증상',
#  '치료 종료 후 진료',
#  '치료 후 또래 것',
#  '최소 치료 종결 후 년 재발 위험',
#  '백혈병 원인',
#  '백혈병 치료 여성 불임 확률',
#  '백혈병 진단 후 우울 때 무어',
#  '백혈병 완치 비법',
#  '백혈병 완치 사례',
#  '백혈병 진단 후 성격 긍정 사례',
#  '제대혈 이식 완치 사례',
#  '골수 이식 완치 사례',
#  '골수 이식 시 준비물',
#  '의사 골수 이식 사례',
#  '진단 후 학습 공백 때',
#  '항암 중 운동',
#  '입원 중 거 시간',
#  '제대혈 기부',
#  '백혈병 생존',
#  '나중 남자 친구 저 병력 얘기 때 지혜 말 것',
#  '암 치료 때 마음 위로 방법',
#  '직장 생활 때 병원 것 때문 회사 직원 어디 얘기 것',
#  '저 병력 저 공동체 집단 소문 대처 것',
#  '건강 관리',
#  '운동 무엇 식',
#  '항암 치료 머리 숱 데 머리숱',
#  '식단 관리 식',
#  '병력 인 차별 편견',
#  '앞 데 건강 때문 불안 마음 때',
#  '친구 둘 머리',
#  '학교 수업',
#  '몸 또래 친구 수',
#  '가발 티',
#  '나 병력 설명 사람 이해 수',
#  '소아 암 치료 지원 수',
#  '평균 소아 암 환자 치료 기간',
#  '소아 암 완치 노력 수',
#  '약 것 약 수',
#  '소아 암 치료 중 고등학교 이익',
#  '암 치료 끝 적응 가능',
#  '암 거 친구',
#  '암 재발 위험 방지 방법',
#  '암 거 이성 교제',
#  '암 식습관',
#  '완치 생활 개선',
#  '암 번 이상',
#  '암 일상생활 트라우마',
#  '암 치료 비용 법',
#  '암 치료 고통 수 방법',
#  '암 재발',
#  '친구 말',
#  '전염',
#  '엄마 아빠 힘',
#  '',
#  '',
#  '치료',
#  '언제 쯤 완치',
#  '유전',
#  '의사 수',
#  '무엇',
#  '집 생활',
#  '밖 외식',
#  '히크 수 운동 무엇',
#  '놀이 기구',
#  '사람',
#  '나 때문 우리 가정',
#  '친구 저',
#  '재발',
#  '',
#  '집안 소독',
#  '정상',
#  '친구 암 치료 말 수 방법',
#  '암 치료 후 사람 암 거',
#  '치료 과정 심리 지원 경험 것 도움',
#  '암 진단 이후 미래 재정 준비 적',
#  '암 진단 이후 울림 말 조언 무엇',
#  '암 진단 때 처음 감정',
#  '가족 친구 질병 것 고민 적',
#  '암 관련 정서 부분 극복',
#  '치료 중 건강 관리',
#  '질병 이유 무엇']

# %% [markdown]
# **Vectorizer 선택**
# - 자연어 처리에서 특징 추출이란? 텍스트 데이터에서 단어나 문장들을 어떤 특징값으로 바꿔주는 것을 의미.
# - 기존에 문자로 구성되어 있던 데이터를 모델에 적용할 수 있도록 특징을 뽑아 어떤 값으로 바꿔서 수치화
#
# *   CountVectorizer: 단순히 각 텍스트에서 단어 빈도 수를 기준으로 특징 추출
# *   HasingVectorizer: CountVectorizer와 동일하지만 hash 함수 사용, 텍스트의 크기가 클수록 효율적
# *   TfidVectorizer: TF-IDF 값을 사용해 텍스트에서 특징 추출

# %%
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfVectorizer

count_vectorizer = CountVectorizer()
hash_vectorizer = HashingVectorizer()
tfidf_vectorizer = TfidfVectorizer()

# %%
# vectorizer 학습
tfidf_vectorizer.fit(data)
vector = tfidf_vectorizer.transform(data).toarray()

from sklearn.cluster import DBSCAN

# DBSCAN 학습
# eps: 문서 사이의 거리, min_samples: cluster를 이루는 최소 문서의 갯수
model = DBSCAN(eps=0.3, min_samples=5, metric="cosine")
result = model.fit_predict(vector)

# %%
# 데이터에 결과 결합
dbscan_df['result'] = result
dbscan_df.head()
# Out:
#                                 question                      nouns  result
# 0                피로도에 따른 쉼을 어떻게 갖고 계십니까?                   [피로도, 쉼]      -1
# 1  암완치자이기 때문에 일반인과 다른 생활 모습은 어떤 것이 있습니까?  [완치자, 때문, 일반인, 생활, 모습, 것]      -1
# 2                 완치자들의 모임을 소개받을 수 있을까요?           [완치자, 모임, 소개, 수]      -1
# 3                    진학관련 상담을 받을 수 있을까요?            [진학, 관련, 상담, 수]      -1
# 4          동일한 병명으로 치료받은 완치자를 만날 수 있을까요?           [병명, 치료, 완치자, 수]      -1

# %%
# 총 몇개의 Clustering이 만들어졌는지 확인
set(result)
# Out:
# {-1, 0, 1, 2, 3, 4}

# %%
# 결과 확인
for cluster_num in set(result):
  # -1, 0 noise, not clustered

  if (cluster_num == -1 or cluster_num == 0):
    continue

  else:
    print("cluster num: {}".format(cluster_num))
    temp_df = dbscan_df[dbscan_df['result'] == cluster_num]
    for question in temp_df['question']:
      print(question)
    print()
# Out:
# cluster num: 1
# 취업면접을볼때 내가 암에걸렸던게 문제가될까요?
# 취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요?
# 면접에서 아팠던 사실을 말하는게 좋을까요?
# 취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요?
# 면접을 볼때 암에 걸렸던걸 먼저 말해야 할까요?
# 취업면접이나 실습면접을 볼 때 내가 암에 걸렸던 것을 말해야할까요?
# 취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요?
#
# cluster num: 2
# 다른 소아암 친구들은 잘하는게 많고 하고싶은게 많은데 그런 친구들을 보니 생각이 많아져요 어떡하면 좋을지 모르겠어요
# 친구들과 가까이 지내고 싶은데 제 안의 벽이 있어요 어떻게 다가가야할까요?
# 친구들이 신기하게 물어보면 자세하게 말하는게 맞을까요..?
# 암걸린거를 친구들에게 알려야하나요
# 친구들한테 말해도될까요?
# 다른친구들이 저랑 안놀까봐 무서워요
#
# cluster num: 3
# 암에 걸려 치료받느라 남들보다 몇 년이나 늦어진게 아쉬워요
# 암을 치료할때 제일 힘들었던 점은?
# 항암 치료 후 재발이 됐을 경우 다른 항암치료에 효과는 그 전 항암치료하고 다를 수도 있나요
# 항암치료 약 들어갈때가 너무힘든데 치료를 하기 싫어요
# 소아암 치료 전 꿈과 치료 후 꿈이 바뀌었나요?
# 치료가어렵나요?
#
# cluster num: 4
# 항암치료를 할 때 안좋게 될까봐 걱정이 많은데 어떻게 해야 할까요?
# 건강에 대해 지나치게 예민해져요. 걱정을 그만하고 싶어요.
# 넘어져서 피가 나면 어떻게 할까 걱정해본 적이 있나요?
# 부모님이 항상 건강을 걱정하시는데 이젠 걱정말라고 할까요?
# 또 암이 걸릴수있을까봐 걱정이 되요 어쩌지요?

# %% [markdown]
# #### 2) BERTopic을 이용한 토픽 모델링
#
# - BERTopic: https://maartengr.github.io/BERTopic/getting_started/parameter%20tuning/parametertuning.html
# - BERTopic 참고문헌2: https://wikidocs.net/162076
# - sbert: https://www.sbert.net/docs/pretrained_models.html

# %%
from bertopic.vectorizers import ClassTfidfTransformer

ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

topic_model = BERTopic(embedding_model= 'paraphrase-multilingual-mpnet-base-v2',
                 ctfidf_model=ctfidf_model,
                 nr_topics = 5,
                 top_n_words = 10,
                 calculate_probabilities=True)

topics, probs = topic_model.fit_transform(my_df)

# %% [markdown]
# **토픽 모델링 결과 - 시각화**

# %%
# 생성된 토픽을 빈도순으로 볼 수 있음
# -1의 값은 outlier에 해당함 (어떤 topic에도 속하지 못한 것)
freq = topic_model.get_topic_info()
freq
# Out:
#    Topic  Count                  Name  \
# 0     -1     17  -1_머리카락이_머리가_빠지고_담배를
# 1      0    275      0_어떻게_있을까요_있는_치료
# 2      1    177       1_소아암_암에_다른_있나요
# 3      2     18      2_되는_먹어도_음식이_음식을
# 4      3     13      3_취업을_직장을_직업을_할때
#
#                                       Representation  \
# 0  [머리카락이, 머리가, 빠지고, 담배를, 자라나요, 기간, 항암, 머리카락은, 전염...
# 1   [어떻게, 있을까요, 있는, 치료, 너무, 학교, 다시, 있나요, 하나요, 궁금합니다]
# 2   [소아암, 암에, 다른, 있나요, 내가, 친구들에게, 치료, 좋을까요, 할까요, 암이]
# 3  [되는, 먹어도, 음식이, 음식을, 음식은, 음식, 먹어야, 집중, 준비물은, 안생기게]
# 4  [취업을, 직장을, 직업을, 할때, 밝히지, 놨으면, 구할때, 해도, 괜찮겠습니까,...
#
#                                  Representative_Docs
# 0  [항암치료로 머리가 많이 빠지고 숱이 없는데 머리숱이 많이지려면 어떻게 해야하는지,...
# 1  [치료 종결 후 진로 고민이 너무 되는데 무얼 어떻게 하면 될지 모르겠어요, 타지에...
# 2  [취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요?, 취업면접을 볼 때 내가...
# 3  [언제까지 음식을 제한하면서 먹어야 하나요? 일상생활하면서 음식을 자유롭게 먹을수 ...
# 4  [취업을 할때 저의 병력을 회사에 밝히는게 좋을까요?, 제가 어떤 직업을 하긴 하는...

# %%
topic_model.get_topic(3) # (topic)에 주로 등장하는 단어 볼 수 있음
# Out:
# [('취업을', 1.0684702724293345),
#  ('직장을', 0.9387884187375805),
#  ('직업을', 0.8724023242614675),
#  ('할때', 0.7889656804323928),
#  ('밝히지', 0.7442077575529862),
#  ('놨으면', 0.7442077575529862),
#  ('구할때', 0.7442077575529862),
#  ('해도', 0.7442077575529862),
#  ('괜찮겠습니까', 0.7442077575529862),
#  ('일을', 0.7442077575529862)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ec689ccd-965a-4af9-9ebc-9849277d6170" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec689ccd-965a-4af9-9ebc-9849277d6170")) {                    Plotly.newPlot(                        "ec689ccd-965a-4af9-9ebc-9849277d6170",                        [{"customdata":[[0,"\uc5b4\ub5bb\uac8c | \uc788\uc744\uae4c\uc694 | \uc788\ub294 | \uce58\ub8cc | \ub108\ubb34",275],[1,"\uc18c\uc544\uc554 | \uc554\uc5d0 | \ub2e4\ub978 | \uc788\ub098\uc694 | \ub0b4\uac00",177],[2,"\ub418\ub294 | \uba39\uc5b4\ub3c4 | \uc74c\uc2dd\uc774 | \uc74c\uc2dd\uc744 | \uc74c\uc2dd\uc740",18],[3,"\ucde8\uc5c5\uc744 | \uc9c1\uc7a5\uc744 | \uc9c1\uc5c5\uc744 | \ud560\ub54c | \ubc1d\ud788\uc9c0",13]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[275,177,18,13],"sizemode":"area","sizeref":0.171875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[14.59891414642334,13.87924575805664,14.980168342590332,13.69077205657959],"xaxis":"x","y":[10.702741622924805,10.241495132446289,9.88447093963623,8.40189266204834],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#3 ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c3f2e967-6282-4810-9a77-a08f1593b401" class="plotly-graph-div" style="height:325.0px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3f2e967-6282-4810-9a77-a08f1593b401")) {                    Plotly.newPlot(                        "c3f2e967-6282-4810-9a77-a08f1593b401",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.30705422753226247,0.3205216953105544,0.33424540820379417,0.3639959477830887,0.41539112928396554],"y":["\ub108\ubb34  ","\uce58\ub8cc  ","\uc788\ub294  ","\uc788\uc744\uae4c\uc694  ","\uc5b4\ub5bb\uac8c  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.34934933143980307,0.37088604281293297,0.39275764459161666,0.41649299612241564,0.4920252769279096],"y":["\ub0b4\uac00  ","\uc788\ub098\uc694  ","\ub2e4\ub978  ","\uc554\uc5d0  ","\uc18c\uc544\uc554  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.9237633038192689,0.9237633038192689,0.9237633038192689,1.0091756815641948,1.0091756815641948],"y":["\uc74c\uc2dd\uc740  ","\uc74c\uc2dd\uc744  ","\uc74c\uc2dd\uc774  ","\uba39\uc5b4\ub3c4  ","\ub418\ub294  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.7442077575529862,0.7889656804323928,0.8724023242614675,0.9387884187375805,1.0684702724293345],"y":["\ubc1d\ud788\uc9c0  ","\ud560\ub54c  ","\uc9c1\uc5c5\uc744  ","\uc9c1\uc7a5\uc744  ","\ucde8\uc5c5\uc744  "],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777 ...

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="796375b5-90ea-48dc-8dc5-b3480eb56df1" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("796375b5-90ea-48dc-8dc5-b3480eb56df1")) {                    Plotly.newPlot(                        "796375b5-90ea-48dc-8dc5-b3480eb56df1",                        [{"coloraxis":"coloraxis","name":"0","x":["0_\uc5b4\ub5bb\uac8c_\uc788\uc744\uae4c\uc694_\uc788\ub294","1_\uc18c\uc544\uc554_\uc554\uc5d0_\ub2e4\ub978","2_\ub418\ub294_\uba39\uc5b4\ub3c4_\uc74c\uc2dd\uc774","3_\ucde8\uc5c5\uc744_\uc9c1\uc7a5\uc744_\uc9c1\uc5c5\uc744"],"y":["0_\uc5b4\ub5bb\uac8c_\uc788\uc744\uae4c\uc694_\uc788\ub294","1_\uc18c\uc544\uc554_\uc554\uc5d0_\ub2e4\ub978","2_\ub418\ub294_\uba39\uc5b4\ub3c4_\uc74c\uc2dd\uc774","3_\ucde8\uc5c5\uc744_\uc9c1\uc7a5\uc744_\uc9c1\uc5c5\uc744"],"z":[[1.0000000000000009,0.6822158216165182,0.5478294920734658,0.614758409643868],[0.6822158216165182,1.0000000000000007,0.46851058256154743,0.3857937130276982],[0.5478294920734658,0.46851058256154743,1.0000000000000013,0.31434944013510446],[0.614758409643868,0.3857937130276982,0.31434944013510446,1.0000000000000004]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3 ...

# %%
topic_model.get_representative_docs()
# Out:
# {-1: ['항암 치료를 하면 머리카락이 다 빠진다고 들었는데 지금도 항암치료, 방사선 치료를 하면서 머리카락이 다 빠지나요?',
#   '뇌종양으로 진단받고 항암 치료가 끝났어도 아직 머리에 남아 있는데 머리에 충격이 그 종양에 나쁜 영향을 미치나요',
#   '머리가 빠지고 머리가 나오는 평균 시간 및 기간에 대해 말해주세요ㆍ숏컷트 기간 ㆍ단발 기간ㆍ어깨 기간 ㆍ예ㅡ1주 1달 3달'],
#  0: ['타지에 살고 있는데 치료병원이 수도권에 있어서 숙박이 어려워요. 소독이 잘되어 있는 숙박시설 있을까요?',
#   '암 치료가 끝난 후 학교로 복귀할 때 친구들과 다시 가까워질 수 있는 방법이 있을까요?',
#   '제 주변에 같이 치료 받았던 친구들이 다 죽었어요. 너무 힘들어요. 어떻게 해야 할까요?'],
#  1: ['취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요?',
#   '취업면접을 볼 때 내가 암에 걸렸던 것을 말해야 할까요?',
#   '소아암 경험자는 삶을 살아가는데 신체적으로 약하고 정신적으로도 상처가 많습니다. 또, 재정적으로도 많이 어려운 경우가 있습니다. 소아암 완치자라고 하더라도 치료 종결 후 사회로 복귀하여 혹독한 환경속에서 악착같이 살아가고 있는 이들을 위해 정말 많은 변화가 필요하고 많은 지원이 필요합니다. '],
#  2: ['언제까지 음식을 제한하면서 먹어야 하나요? 일상생활하면서 음식을 자유롭게 먹을수 있을까요?',
#   '치료 중 먹어도 되는 음식, 안되는 음식, 이것을 먹어도 될까요?',
#   '집중 치료 기간 동안 먹어도 되는 음식은?'],
#  3: ['취업을 할때 저의 병력을 회사에 밝히는게 좋을까요?',
#   '제가 어떤 직업을 하긴 하는데, 다른 직업도 생각해 놨으면 어떻게 합니까?',
#   '아무리 심한 휴유증을 앓고 있더라도 실습이나 취업을 가능하게 해줍니까?']}

# %%
new_question = '하루 하루가 너무 피곤하고 지쳐요. 어떻게 하면 좋을까요?'
topics, probs = topic_model.transform([new_question])
print('예측한 토픽 번호:', topics)
# Out:
# 예측한 토픽 번호: [-1]
